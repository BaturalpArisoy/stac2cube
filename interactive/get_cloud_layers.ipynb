# %% [markdown]
# # Interactive Script: **get_cloud_layers**
#
# **Author:** Baturalp Arisoy
#
# ## Contents
#
# 1. [How to **get_cloud_layers**](#1-how-to-get_cloud_layers)
# 2.
#
# ---

# %% [markdown]
# **Imports**

# %%
from stac2ardcube import get_cloud_layers
import xarray as xr

# %% [markdown]
# ## 1. How to **get_cloud_layers**

# %% [markdown]
# > **Note:**<br>
# > **get_cloud_layers** cannot return lazy array because s2cloudless algorithm must be applied to computed data. Therefore, use the following cells if you are on a machine with a strong computational power.<br>  Otherwise, use HPC Slurm job and read the NETCDF file below

# %% [markdown]
# **1.1 Set the parameters**

# %%
mission = "s2"
polygon = "./polygons/test.gpkg"
resolution = 10
daterange = ["2022-01-01", "2024-12-31"]
bands = ["blue", "green", "red", "nir",]
max_cc = 100
clip_raster = False
cloud_masking = False
indices = ["ndvi", "ndwi"]
output = None
stats = None
aggregator = None
topographic_features = None
animation = False

# %% [markdown]
# **1.2 Get Cloud Layers as exported NETCDF**

# %%
cloud_stac = get_stac_layers(mission=mission, polygon=polygon, resolution=resolution, 
                            daterange=daterange, bands=bands, max_cc=max_cc, 
                            clip_raster=clip_raster, cloud_masking=cloud_masking, indices=indices, 
                            output=output, aggregator=aggregator, stats=stats,
                            topographic_features=topographic_features, animation=animation)

# %% [markdown]
# **1.3 Read the file exported with HPC Slurm from DSS container**

# %%
cloud_stac = "/dss/dsstbyfs02/pr94no/pr94no-dss-0001/drylands/results/naryn_latest_cloud.nc"


cloud = xr.open_dataset(cloud_stac)
cloud = cloud.Cloud_Stack

# %%
cloud
# Out:
# <xarray.DataArray 'Cloud_Stack' (time: 9, band: 2, y: 470, x: 1277)> Size: 43MB
# [10803420 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 72B 2022-01-05T05:57:35.206000 ... 2022-02...
#   * y        (y) float64 4kB 4.583e+06 4.583e+06 ... 4.578e+06 4.578e+06
#   * x        (x) float64 10kB 5.344e+05 5.344e+05 ... 5.471e+05 5.471e+05
#   * band     (band) <U10 80B 'cloud_prob' 'cloud_mask'
# Attributes:
#     grid_mapping:  spatial_ref
