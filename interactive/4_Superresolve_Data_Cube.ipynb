# %% [markdown]
# # Interactive Script: **Super-resolve Data Cube**
#
# **Author:** Baturalp Arisoy<br>
# **Contact:** baturalp.arisoy@uni-wuerzburg.de - Call me Batu :)
#
# ## Overview
# This notebook guides the user through the essentials of super resolution of the time-series data cube.

# %%
from stac2cube import super_resolve_cube

# %% [markdown]
# - Sen2SR provides several models, each model needs exact required of the S2 spectral bands. In stac2cube, two of the Sen2SR models are used:
# 1) RGBN - SEN2SRLite_RGBN (10-m bands)
# 2) Full Spectral - SEN2SRLite (10 and 20-m bands)

# %% [markdown]
# ## 1. RGBN

# %% [markdown]
# - Required band setup (order of the bands is taken care in the background) -> bands = ["blue", "green", "red", "nir"] <br><br>
# - If exist, indices must be only 10-meter resolution ones, e.g., indices = ["ndvi", "ndwi"] <br><br>
# - Use this model if you don't have 20-m bands. Much faster model!

# %%
super_resolve_cube(input_path= "./results/test.nc",
                    output_path = None, # If None, will write result under the same folder of input with extra prefix "_sr.nc",
                    model_type = "rgbn"
 )

# %% [markdown]
# ## 2. Full Spectral

# %% [markdown]
# - Required band setup (order of the bands is taken care in the background) -> bands = ["blue", "green", "red", "nir", "nir08", "rededge1", "rededge2", "rededge3", "swir16", "swir22"] <br><br>
# - If exist, indices can be both 10 and 20-meter resolution ones, e.g., indices = ["ndvi", "ndwi", "ndmi"] <br><br>
# - Use this model only if you need to super resolve 20-meter bands.<br><br>
# - Even if you need to super-resolve one of the 20-meter bands, still need to include all of the required ones.

# %%
super_resolve_cube(input_path= "./results/test.nc",
                    output_path = None, # If None, will write result under the same folder of input with extra prefix "_sr.nc",
                    model_type = "full_spectral"
 )
